# %% [markdown]
# # LAB 3 Stock Lookups

# %% [markdown]
# ## Set Envirornment for Stock Lookups

# %%
import pandas as pd
import fix_yahoo_finance as yf
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Obtain top 3 Entities with stock values as first and fina iteration

# %%
data = yf.download("YAHOY", start="2013-01-01", end="2013-12-31")
data1YahooJapan = data.Close
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
# %pylab inline
data1YahooJapan.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = yf.download("EFX", start="2017-01-01", end="2017-10-06")
data2Equifax = data.Close
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
# %pylab inline
data2Equifax.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = yf.download("HTLD", start="2009-01-01", end="2009-12-31")
data3Heartland = data.Close
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
# %pylab inline
data3Heartland.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Given that the data supports a negative short-term effect on the Financial Markets, additional study could show the specific recovery times of the losses

# %% [markdown]
# ## Write Stock data to file for Tableau upload

# %%
data1YahooJapan.to_csv('data1YahooJapan.csv')
data2Equifax.to_csv('data2Equifax.csv')
data3Heartland.to_csv('data3Heartland.csv')
